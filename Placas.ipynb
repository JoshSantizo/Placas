# %%
import cv2
import pytesseract
import matplotlib.pyplot as plt
pytesseract.pytesseract.tesseract_cmd = r"C:\Users\jsant\AppData\Local\Programs\Tesseract-OCR"

# %%
placa = []
archivo1 = "Imagenes/big_with_watermark_3.jpg"
archivo2 = "Imagenes/big_with_watermark_5-29.jpg"
archivo3 = "Imagenes/big_with_watermark_91.2.jpg"
archivo4 = "Imagenes/EJERCITO Y PNC2.jpg"
archivo = archivo4
image = cv2.imread(archivo)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap="gray");

# %%
gray = cv2.blur(gray, (3,3))
plt.imshow(gray, cmap="gray");

# %%
canny = cv2.Canny(gray, 150, 200)
plt.imshow(canny, cmap="gray");

# %%
canny = cv2.dilate(canny, None, iterations = 1)
plt.imshow(canny, cmap="gray");

# %%
_, cnts, = cv2.findContours(canny, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE) #OPEN CV3

# %%
for c in cnts:
    area = cv2.contourArea(c)
    x,y,z,h = cv2.boundingRect(c)
    epsilon = 0.09 * cv2.arcLength(c, True)
    approx = cv2.approxPolyDPp(c, epsilon, True)
    
    if len(approx) == and area > 9000:
        print("area: ", area)
        print("w", w)
        rint("h", h)
        aspect_ratio = float(w)/h
        print("Relacion de aspecto: ", aspect_ratio)
        cv2.drawContours(image, [approx], 0, (0,255,0),3)
        
        if aspect_ratio = 3
        placa = gray[y:y+h, x:x+w]
        text = pytesseract.image_to_string(placa, config="--psm 11").strip()
        print ("placa", text)
        cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0),1)
        cv2.putText(image, text, (x=20, y=10),1,2.2,(0,255,0),3)
